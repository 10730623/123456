# %% [markdown]
# Use shift-enter to execute a code block and move to the next one.

# %%
# 1.1 Import tensorflow and other libraries.
import tensorflow as tf
import numpy as np

# %matplotlib inline
import pylab

# %%
# 1.2 Create input data using NumPy. y = x * 0.1 + 0.3 + noise
#x_data = np.random.rand(50).astype(np.float32)
#noise = np.random.normal(scale=0.01, size=len(x_data))
#y_data = x_data * 2-5 + noise
x_data = np.linspace( -30,50,1000)
y_data = 100000-(200/(x_data+3.5)-2*x_data)
# Uncomment the following line to plot our input data.
pylab.plot(x_data, y_data, '.')

# %%
# 1.3 Buld inference graph.
# Create Variables W and b that compute y_data = W * x_data + b
y = tf.Variable(tf.random_uniform([1], 0.0,30.0, ))
#b = tf.Variable(tf.zeros([1]))
#y =  (200/(x+3.5)-2)*x

# Uncomment the following lines to see W and b are.
#print(x_data)
#print(y_data)

# %%
# 1.4 Build training graph.
loss = tf.reduce_mean(10000-(200/(y+3.5)-2)*y)  # Create an operation that calculates loss.
optimizer = tf.train.GradientDescentOptimizer(1)  # Create an optimizer.
train = optimizer.minimize(loss)  # Create an operation that minimizes loss.
init = tf.initialize_all_variables()  # Create an operation initializes all the variables.

# Uncomment the following 3 lines to see what 'loss', 'optimizer' and 'train' are.
#print("loss:", loss)
#print("optimizer:", optimizer)
#print("train:", train)
#print(init)

# %%
# 1.5 Uncomment the following line to see what we have built.
print(tf.get_default_graph().as_graph_def())
# Out:
# node {
#   name: "random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 30.0
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "random_uniform/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "random_uniform/sub"
#   op: "Sub"
#   input: "random_uniform/max"
#   input: "random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "random_uniform/mul"
#   op: "Mul"
#   input: "random_uniform/RandomUniform"
#   input: "random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "random_uniform"
#   op: "Add"
#   input: "random_uniform/mul"
#   input: "random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Variable"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "Variable/Assign"
#   op: "Assign"
#   input: "Variable"
#   input: "random_uniform"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Variable/read"
#   op: "Identity"
#   input: "Variable"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable"
#       }
#     }
#   }
# }
# node {
#   name: "add/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 3.5
#       }
#     }
#   }
# }
# node {
#   name: "add"
#   op: "Add"
#   input: "Variable/read"
#   input: "add/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "div/x"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 200.0
#       }
#     }
#   }
# }
# node {
#   name: "div"
#   op: "RealDiv"
#   input: "div/x"
#   input: "add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sub/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 2.0
#       }
#     }
#   }
# }
# node {
#   name: "sub"
#   op: "Sub"
#   input: "div"
#   input: "sub/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "mul"
#   op: "Mul"
#   input: "sub"
#   input: "Variable/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Mean"
#   op: "Mean"
#   input: "mul"
#   input: "Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients/grad_ys_0"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "gradients/Fill"
#   op: "Fill"
#   input: "gradients/Shape"
#   input: "gradients/grad_ys_0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "index_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/Mean_grad/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/Mean_grad/Reshape"
#   op: "Reshape"
#   input: "gradients/Fill"
#   input: "gradients/Mean_grad/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/Mean_grad/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/Mean_grad/Tile"
#   op: "Tile"
#   input: "gradients/Mean_grad/Reshape"
#   input: "gradients/Mean_grad/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tmultiples"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/Mean_grad/Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "gradients/Mean_grad/truediv"
#   op: "RealDiv"
#   input: "gradients/Mean_grad/Tile"
#   input: "gradients/Mean_grad/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/mul_grad/Mul"
#   op: "Mul"
#   input: "gradients/Mean_grad/truediv"
#   input: "Variable/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/mul_grad/Mul_1"
#   op: "Mul"
#   input: "gradients/Mean_grad/truediv"
#   input: "sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/mul_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients/mul_grad/Mul"
#   input: "^gradients/mul_grad/Mul_1"
# }
# node {
#   name: "gradients/mul_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients/mul_grad/Mul"
#   input: "^gradients/mul_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/mul_grad/Mul"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/mul_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients/mul_grad/Mul_1"
#   input: "^gradients/mul_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/mul_grad/Mul_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/BroadcastGradientArgs"
#   op: "BroadcastGradientArgs"
#   input: "gradients/sub_grad/Shape"
#   input: "gradients/sub_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/Sum"
#   op: "Sum"
#   input: "gradients/mul_grad/tuple/control_dependency"
#   input: "gradients/sub_grad/BroadcastGradientArgs"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/Reshape"
#   op: "Reshape"
#   input: "gradients/sub_grad/Sum"
#   input: "gradients/sub_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/Sum_1"
#   op: "Sum"
#   input: "gradients/mul_grad/tuple/control_dependency"
#   input: "gradients/sub_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/Neg"
#   op: "Neg"
#   input: "gradients/sub_grad/Sum_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients/sub_grad/Neg"
#   input: "gradients/sub_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients/sub_grad/Reshape"
#   input: "^gradients/sub_grad/Reshape_1"
# }
# node {
#   name: "gradients/sub_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients/sub_grad/Reshape"
#   input: "^gradients/sub_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/sub_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/sub_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients/sub_grad/Reshape_1"
#   input: "^gradients/sub_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/sub_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/BroadcastGradientArgs"
#   op: "BroadcastGradientArgs"
#   input: "gradients/div_grad/Shape"
#   input: "gradients/div_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/RealDiv"
#   op: "RealDiv"
#   input: "gradients/sub_grad/tuple/control_dependency"
#   input: "add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/Sum"
#   op: "Sum"
#   input: "gradients/div_grad/RealDiv"
#   input: "gradients/div_grad/BroadcastGradientArgs"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/Reshape"
#   op: "Reshape"
#   input: "gradients/div_grad/Sum"
#   input: "gradients/div_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/Neg"
#   op: "Neg"
#   input: "div/x"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/RealDiv_1"
#   op: "RealDiv"
#   input: "gradients/div_grad/Neg"
#   input: "add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/RealDiv_2"
#   op: "RealDiv"
#   input: "gradients/div_grad/RealDiv_1"
#   input: "add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/mul"
#   op: "Mul"
#   input: "gradients/sub_grad/tuple/control_dependency"
#   input: "gradients/div_grad/RealDiv_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/Sum_1"
#   op: "Sum"
#   input: "gradients/div_grad/mul"
#   input: "gradients/div_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients/div_grad/Sum_1"
#   input: "gradients/div_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients/div_grad/Reshape"
#   input: "^gradients/div_grad/Reshape_1"
# }
# node {
#   name: "gradients/div_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients/div_grad/Reshape"
#   input: "^gradients/div_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/div_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/div_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients/div_grad/Reshape_1"
#   input: "^gradients/div_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/div_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/add_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients/add_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients/add_grad/BroadcastGradientArgs"
#   op: "BroadcastGradientArgs"
#   input: "gradients/add_grad/Shape"
#   input: "gradients/add_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/add_grad/Sum"
#   op: "Sum"
#   input: "gradients/div_grad/tuple/control_dependency_1"
#   input: "gradients/add_grad/BroadcastGradientArgs"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/add_grad/Reshape"
#   op: "Reshape"
#   input: "gradients/add_grad/Sum"
#   input: "gradients/add_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/add_grad/Sum_1"
#   op: "Sum"
#   input: "gradients/div_grad/tuple/control_dependency_1"
#   input: "gradients/add_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/add_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients/add_grad/Sum_1"
#   input: "gradients/add_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients/add_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients/add_grad/Reshape"
#   input: "^gradients/add_grad/Reshape_1"
# }
# node {
#   name: "gradients/add_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients/add_grad/Reshape"
#   input: "^gradients/add_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/add_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/add_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients/add_grad/Reshape_1"
#   input: "^gradients/add_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/add_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients/AddN"
#   op: "AddN"
#   input: "gradients/mul_grad/tuple/control_dependency_1"
#   input: "gradients/add_grad/tuple/control_dependency"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients/mul_grad/Mul_1"
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent/learning_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.5
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent/update_Variable/ApplyGradientDescent"
#   op: "ApplyGradientDescent"
#   input: "Variable"
#   input: "GradientDescent/learning_rate"
#   input: "gradients/AddN"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "GradientDescent"
#   op: "NoOp"
#   input: "^GradientDescent/update_Variable/ApplyGradientDescent"
# }
# node {
#   name: "init"
#   op: "NoOp"
#   input: "^Variable/Assign"
# }
# node {
#   name: "random_uniform_1/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform_1/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform_1/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 30.0
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform_1/RandomUniform"
#   op: "RandomUniform"
#   input: "random_uniform_1/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "random_uniform_1/sub"
#   op: "Sub"
#   input: "random_uniform_1/max"
#   input: "random_uniform_1/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "random_uniform_1/mul"
#   op: "Mul"
#   input: "random_uniform_1/RandomUniform"
#   input: "random_uniform_1/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "random_uniform_1"
#   op: "Add"
#   input: "random_uniform_1/mul"
#   input: "random_uniform_1/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Variable_1"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "Variable_1/Assign"
#   op: "Assign"
#   input: "Variable_1"
#   input: "random_uniform_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Variable_1/read"
#   op: "Identity"
#   input: "Variable_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
# }
# node {
#   name: "add_1/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 3.5
#       }
#     }
#   }
# }
# node {
#   name: "add_1"
#   op: "Add"
#   input: "Variable_1/read"
#   input: "add_1/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "div_1/x"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 200.0
#       }
#     }
#   }
# }
# node {
#   name: "div_1"
#   op: "RealDiv"
#   input: "div_1/x"
#   input: "add_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sub_1/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 2.0
#       }
#     }
#   }
# }
# node {
#   name: "sub_1"
#   op: "Sub"
#   input: "div_1"
#   input: "sub_1/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "mul_1"
#   op: "Mul"
#   input: "sub_1"
#   input: "Variable_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Mean_1"
#   op: "Mean"
#   input: "mul_1"
#   input: "Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_1/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/grad_ys_0"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/Fill"
#   op: "Fill"
#   input: "gradients_1/Shape"
#   input: "gradients_1/grad_ys_0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "index_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/Mean_1_grad/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/Mean_1_grad/Reshape"
#   op: "Reshape"
#   input: "gradients_1/Fill"
#   input: "gradients_1/Mean_1_grad/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/Mean_1_grad/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/Mean_1_grad/Tile"
#   op: "Tile"
#   input: "gradients_1/Mean_1_grad/Reshape"
#   input: "gradients_1/Mean_1_grad/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tmultiples"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/Mean_1_grad/Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/Mean_1_grad/truediv"
#   op: "RealDiv"
#   input: "gradients_1/Mean_1_grad/Tile"
#   input: "gradients_1/Mean_1_grad/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_1/mul_1_grad/Mul"
#   op: "Mul"
#   input: "gradients_1/Mean_1_grad/truediv"
#   input: "Variable_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_1/mul_1_grad/Mul_1"
#   op: "Mul"
#   input: "gradients_1/Mean_1_grad/truediv"
#   input: "sub_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_1/mul_1_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_1/mul_1_grad/Mul"
#   input: "^gradients_1/mul_1_grad/Mul_1"
# }
# node {
#   name: "gradients_1/mul_1_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_1/mul_1_grad/Mul"
#   input: "^gradients_1/mul_1_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_1/mul_1_grad/Mul"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/mul_1_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_1/mul_1_grad/Mul_1"
#   input: "^gradients_1/mul_1_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_1/mul_1_grad/Mul_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/BroadcastGradientArgs"
#   op: "BroadcastGradientArgs"
#   input: "gradients_1/sub_1_grad/Shape"
#   input: "gradients_1/sub_1_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/Sum"
#   op: "Sum"
#   input: "gradients_1/mul_1_grad/tuple/control_dependency"
#   input: "gradients_1/sub_1_grad/BroadcastGradientArgs"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/Reshape"
#   op: "Reshape"
#   input: "gradients_1/sub_1_grad/Sum"
#   input: "gradients_1/sub_1_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/Sum_1"
#   op: "Sum"
#   input: "gradients_1/mul_1_grad/tuple/control_dependency"
#   input: "gradients_1/sub_1_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/Neg"
#   op: "Neg"
#   input: "gradients_1/sub_1_grad/Sum_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients_1/sub_1_grad/Neg"
#   input: "gradients_1/sub_1_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_1/sub_1_grad/Reshape"
#   input: "^gradients_1/sub_1_grad/Reshape_1"
# }
# node {
#   name: "gradients_1/sub_1_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_1/sub_1_grad/Reshape"
#   input: "^gradients_1/sub_1_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_1/sub_1_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/sub_1_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_1/sub_1_grad/Reshape_1"
#   input: "^gradients_1/sub_1_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_1/sub_1_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/BroadcastGradientArgs"
#   op: "BroadcastGradientArgs"
#   input: "gradients_1/div_1_grad/Shape"
#   input: "gradients_1/div_1_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/RealDiv"
#   op: "RealDiv"
#   input: "gradients_1/sub_1_grad/tuple/control_dependency"
#   input: "add_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/Sum"
#   op: "Sum"
#   input: "gradients_1/div_1_grad/RealDiv"
#   input: "gradients_1/div_1_grad/BroadcastGradientArgs"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/Reshape"
#   op: "Reshape"
#   input: "gradients_1/div_1_grad/Sum"
#   input: "gradients_1/div_1_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/Neg"
#   op: "Neg"
#   input: "div_1/x"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/RealDiv_1"
#   op: "RealDiv"
#   input: "gradients_1/div_1_grad/Neg"
#   input: "add_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/RealDiv_2"
#   op: "RealDiv"
#   input: "gradients_1/div_1_grad/RealDiv_1"
#   input: "add_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/mul"
#   op: "Mul"
#   input: "gradients_1/sub_1_grad/tuple/control_dependency"
#   input: "gradients_1/div_1_grad/RealDiv_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/Sum_1"
#   op: "Sum"
#   input: "gradients_1/div_1_grad/mul"
#   input: "gradients_1/div_1_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients_1/div_1_grad/Sum_1"
#   input: "gradients_1/div_1_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_1/div_1_grad/Reshape"
#   input: "^gradients_1/div_1_grad/Reshape_1"
# }
# node {
#   name: "gradients_1/div_1_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_1/div_1_grad/Reshape"
#   input: "^gradients_1/div_1_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_1/div_1_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/div_1_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_1/div_1_grad/Reshape_1"
#   input: "^gradients_1/div_1_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_1/div_1_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/add_1_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/add_1_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/add_1_grad/BroadcastGradientArgs"
#   op: "BroadcastGradientArgs"
#   input: "gradients_1/add_1_grad/Shape"
#   input: "gradients_1/add_1_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/add_1_grad/Sum"
#   op: "Sum"
#   input: "gradients_1/div_1_grad/tuple/control_dependency_1"
#   input: "gradients_1/add_1_grad/BroadcastGradientArgs"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_1/add_1_grad/Reshape"
#   op: "Reshape"
#   input: "gradients_1/add_1_grad/Sum"
#   input: "gradients_1/add_1_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/add_1_grad/Sum_1"
#   op: "Sum"
#   input: "gradients_1/div_1_grad/tuple/control_dependency_1"
#   input: "gradients_1/add_1_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_1/add_1_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients_1/add_1_grad/Sum_1"
#   input: "gradients_1/add_1_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_1/add_1_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_1/add_1_grad/Reshape"
#   input: "^gradients_1/add_1_grad/Reshape_1"
# }
# node {
#   name: "gradients_1/add_1_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_1/add_1_grad/Reshape"
#   input: "^gradients_1/add_1_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_1/add_1_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/add_1_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_1/add_1_grad/Reshape_1"
#   input: "^gradients_1/add_1_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_1/add_1_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_1/AddN"
#   op: "AddN"
#   input: "gradients_1/mul_1_grad/tuple/control_dependency_1"
#   input: "gradients_1/add_1_grad/tuple/control_dependency"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_1/mul_1_grad/Mul_1"
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent_1/learning_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.5
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent_1/update_Variable_1/ApplyGradientDescent"
#   op: "ApplyGradientDescent"
#   input: "Variable_1"
#   input: "GradientDescent_1/learning_rate"
#   input: "gradients_1/AddN"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "GradientDescent_1"
#   op: "NoOp"
#   input: "^GradientDescent_1/update_Variable_1/ApplyGradientDescent"
# }
# node {
#   name: "init_1"
#   op: "NoOp"
#   input: "^Variable/Assign"
#   input: "^Variable_1/Assign"
# }
# node {
#   name: "random_uniform_2/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform_2/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform_2/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 30.0
#       }
#     }
#   }
# }
# node {
#   name: "random_uniform_2/RandomUniform"
#   op: "RandomUniform"
#   input: "random_uniform_2/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "random_uniform_2/sub"
#   op: "Sub"
#   input: "random_uniform_2/max"
#   input: "random_uniform_2/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "random_uniform_2/mul"
#   op: "Mul"
#   input: "random_uniform_2/RandomUniform"
#   input: "random_uniform_2/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "random_uniform_2"
#   op: "Add"
#   input: "random_uniform_2/mul"
#   input: "random_uniform_2/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Variable_2"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "Variable_2/Assign"
#   op: "Assign"
#   input: "Variable_2"
#   input: "random_uniform_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_2"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Variable_2/read"
#   op: "Identity"
#   input: "Variable_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_2"
#       }
#     }
#   }
# }
# node {
#   name: "add_2/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 3.5
#       }
#     }
#   }
# }
# node {
#   name: "add_2"
#   op: "Add"
#   input: "Variable_2/read"
#   input: "add_2/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "div_2/x"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 200.0
#       }
#     }
#   }
# }
# node {
#   name: "div_2"
#   op: "RealDiv"
#   input: "div_2/x"
#   input: "add_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sub_2/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 2.0
#       }
#     }
#   }
# }
# node {
#   name: "sub_2"
#   op: "Sub"
#   input: "div_2"
#   input: "sub_2/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "mul_2"
#   op: "Mul"
#   input: "sub_2"
#   input: "Variable_2/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Const_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "Mean_2"
#   op: "Mean"
#   input: "mul_2"
#   input: "Const_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_2/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients_2/grad_ys_0"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "gradients_2/Fill"
#   op: "Fill"
#   input: "gradients_2/Shape"
#   input: "gradients_2/grad_ys_0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "index_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_2/Mean_2_grad/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_2/Mean_2_grad/Reshape"
#   op: "Reshape"
#   input: "gradients_2/Fill"
#   input: "gradients_2/Mean_2_grad/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_2/Mean_2_grad/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_2/Mean_2_grad/Tile"
#   op: "Tile"
#   input: "gradients_2/Mean_2_grad/Reshape"
#   input: "gradients_2/Mean_2_grad/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tmultiples"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_2/Mean_2_grad/Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "gradients_2/Mean_2_grad/truediv"
#   op: "RealDiv"
#   input: "gradients_2/Mean_2_grad/Tile"
#   input: "gradients_2/Mean_2_grad/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_2/mul_2_grad/Mul"
#   op: "Mul"
#   input: "gradients_2/Mean_2_grad/truediv"
#   input: "Variable_2/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_2/mul_2_grad/Mul_1"
#   op: "Mul"
#   input: "gradients_2/Mean_2_grad/truediv"
#   input: "sub_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_2/mul_2_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_2/mul_2_grad/Mul"
#   input: "^gradients_2/mul_2_grad/Mul_1"
# }
# node {
#   name: "gradients_2/mul_2_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_2/mul_2_grad/Mul"
#   input: "^gradients_2/mul_2_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_2/mul_2_grad/Mul"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_2/mul_2_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_2/mul_2_grad/Mul_1"
#   input: "^gradients_2/mul_2_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_2/mul_2_grad/Mul_1"
#       }
#     }
# ...
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_36_grad/Sum_1"
#   op: "Sum"
#   input: "gradients_22/Mean_22_grad/truediv"
#   input: "gradients_22/sub_36_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_36_grad/Neg"
#   op: "Neg"
#   input: "gradients_22/sub_36_grad/Sum_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_36_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients_22/sub_36_grad/Neg"
#   input: "gradients_22/sub_36_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_36_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_22/sub_36_grad/Reshape"
#   input: "^gradients_22/sub_36_grad/Reshape_1"
# }
# node {
#   name: "gradients_22/sub_36_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_22/sub_36_grad/Reshape"
#   input: "^gradients_22/sub_36_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/sub_36_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_36_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_22/sub_36_grad/Reshape_1"
#   input: "^gradients_22/sub_36_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/sub_36_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/mul_22_grad/Mul"
#   op: "Mul"
#   input: "gradients_22/sub_36_grad/tuple/control_dependency_1"
#   input: "Variable_22/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_22/mul_22_grad/Mul_1"
#   op: "Mul"
#   input: "gradients_22/sub_36_grad/tuple/control_dependency_1"
#   input: "sub_35"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_22/mul_22_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_22/mul_22_grad/Mul"
#   input: "^gradients_22/mul_22_grad/Mul_1"
# }
# node {
#   name: "gradients_22/mul_22_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_22/mul_22_grad/Mul"
#   input: "^gradients_22/mul_22_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/mul_22_grad/Mul"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/mul_22_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_22/mul_22_grad/Mul_1"
#   input: "^gradients_22/mul_22_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/mul_22_grad/Mul_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/BroadcastGradientArgs"
#   op: "BroadcastGradientArgs"
#   input: "gradients_22/sub_35_grad/Shape"
#   input: "gradients_22/sub_35_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/Sum"
#   op: "Sum"
#   input: "gradients_22/mul_22_grad/tuple/control_dependency"
#   input: "gradients_22/sub_35_grad/BroadcastGradientArgs"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/Reshape"
#   op: "Reshape"
#   input: "gradients_22/sub_35_grad/Sum"
#   input: "gradients_22/sub_35_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/Sum_1"
#   op: "Sum"
#   input: "gradients_22/mul_22_grad/tuple/control_dependency"
#   input: "gradients_22/sub_35_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/Neg"
#   op: "Neg"
#   input: "gradients_22/sub_35_grad/Sum_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients_22/sub_35_grad/Neg"
#   input: "gradients_22/sub_35_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_22/sub_35_grad/Reshape"
#   input: "^gradients_22/sub_35_grad/Reshape_1"
# }
# node {
#   name: "gradients_22/sub_35_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_22/sub_35_grad/Reshape"
#   input: "^gradients_22/sub_35_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/sub_35_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/sub_35_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_22/sub_35_grad/Reshape_1"
#   input: "^gradients_22/sub_35_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/sub_35_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/BroadcastGradientArgs"
#   op: "BroadcastGradientArgs"
#   input: "gradients_22/div_22_grad/Shape"
#   input: "gradients_22/div_22_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/RealDiv"
#   op: "RealDiv"
#   input: "gradients_22/sub_35_grad/tuple/control_dependency"
#   input: "add_22"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/Sum"
#   op: "Sum"
#   input: "gradients_22/div_22_grad/RealDiv"
#   input: "gradients_22/div_22_grad/BroadcastGradientArgs"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/Reshape"
#   op: "Reshape"
#   input: "gradients_22/div_22_grad/Sum"
#   input: "gradients_22/div_22_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/Neg"
#   op: "Neg"
#   input: "div_22/x"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/RealDiv_1"
#   op: "RealDiv"
#   input: "gradients_22/div_22_grad/Neg"
#   input: "add_22"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/RealDiv_2"
#   op: "RealDiv"
#   input: "gradients_22/div_22_grad/RealDiv_1"
#   input: "add_22"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/mul"
#   op: "Mul"
#   input: "gradients_22/sub_35_grad/tuple/control_dependency"
#   input: "gradients_22/div_22_grad/RealDiv_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/Sum_1"
#   op: "Sum"
#   input: "gradients_22/div_22_grad/mul"
#   input: "gradients_22/div_22_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients_22/div_22_grad/Sum_1"
#   input: "gradients_22/div_22_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_22/div_22_grad/Reshape"
#   input: "^gradients_22/div_22_grad/Reshape_1"
# }
# node {
#   name: "gradients_22/div_22_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_22/div_22_grad/Reshape"
#   input: "^gradients_22/div_22_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/div_22_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/div_22_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_22/div_22_grad/Reshape_1"
#   input: "^gradients_22/div_22_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/div_22_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/add_22_grad/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/add_22_grad/Shape_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/add_22_grad/BroadcastGradientArgs"
#   op: "BroadcastGradientArgs"
#   input: "gradients_22/add_22_grad/Shape"
#   input: "gradients_22/add_22_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/add_22_grad/Sum"
#   op: "Sum"
#   input: "gradients_22/div_22_grad/tuple/control_dependency_1"
#   input: "gradients_22/add_22_grad/BroadcastGradientArgs"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_22/add_22_grad/Reshape"
#   op: "Reshape"
#   input: "gradients_22/add_22_grad/Sum"
#   input: "gradients_22/add_22_grad/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/add_22_grad/Sum_1"
#   op: "Sum"
#   input: "gradients_22/div_22_grad/tuple/control_dependency_1"
#   input: "gradients_22/add_22_grad/BroadcastGradientArgs:1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients_22/add_22_grad/Reshape_1"
#   op: "Reshape"
#   input: "gradients_22/add_22_grad/Sum_1"
#   input: "gradients_22/add_22_grad/Shape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "gradients_22/add_22_grad/tuple/group_deps"
#   op: "NoOp"
#   input: "^gradients_22/add_22_grad/Reshape"
#   input: "^gradients_22/add_22_grad/Reshape_1"
# }
# node {
#   name: "gradients_22/add_22_grad/tuple/control_dependency"
#   op: "Identity"
#   input: "gradients_22/add_22_grad/Reshape"
#   input: "^gradients_22/add_22_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/add_22_grad/Reshape"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/add_22_grad/tuple/control_dependency_1"
#   op: "Identity"
#   input: "gradients_22/add_22_grad/Reshape_1"
#   input: "^gradients_22/add_22_grad/tuple/group_deps"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/add_22_grad/Reshape_1"
#       }
#     }
#   }
# }
# node {
#   name: "gradients_22/AddN"
#   op: "AddN"
#   input: "gradients_22/mul_22_grad/tuple/control_dependency_1"
#   input: "gradients_22/add_22_grad/tuple/control_dependency"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@gradients_22/mul_22_grad/Mul_1"
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent_22/learning_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent_22/update_Variable_22/Cast"
#   op: "Cast"
#   input: "GradientDescent_22/learning_rate"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Truncate"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_22"
#       }
#     }
#   }
# }
# node {
#   name: "GradientDescent_22/update_Variable_22/ApplyGradientDescent"
#   op: "ApplyGradientDescent"
#   input: "Variable_22"
#   input: "GradientDescent_22/update_Variable_22/Cast"
#   input: "gradients_22/AddN"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_22"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "GradientDescent_22"
#   op: "NoOp"
#   input: "^GradientDescent_22/update_Variable_22/ApplyGradientDescent"
# }
# node {
#   name: "init_22"
#   op: "NoOp"
#   input: "^Variable/Assign"
#   input: "^Variable_1/Assign"
#   input: "^Variable_10/Assign"
#   input: "^Variable_11/Assign"
#   input: "^Variable_12/Assign"
#   input: "^Variable_13/Assign"
#   input: "^Variable_14/Assign"
#   input: "^Variable_15/Assign"
#   input: "^Variable_16/Assign"
#   input: "^Variable_17/Assign"
#   input: "^Variable_18/Assign"
#   input: "^Variable_19/Assign"
#   input: "^Variable_2/Assign"
#   input: "^Variable_20/Assign"
#   input: "^Variable_21/Assign"
#   input: "^Variable_22/Assign"
#   input: "^Variable_3/Assign"
#   input: "^Variable_4/Assign"
#   input: "^Variable_5/Assign"
#   input: "^Variable_6/Assign"
#   input: "^Variable_7/Assign"
#   input: "^Variable_8/Assign"
#   input: "^Variable_9/Assign"
# }
# versions {
#   producer: 27
# }

# %%
# 1.6 Create a session and launch the graph.
sess = tf.Session()
sess.run(init)
y_initial_values = sess.run(y)  # Save initial values for plotting later.

# Uncomment the following line to see the initial W and b values.
print(sess.run([y]))
# Out:
# [array([13.300846], dtype=float32)]

# %%
# 1.7 Perform training.
for step in range(201):
    sess.run(train)
    # Uncomment the following two lines to watch training happen real time.
  #  if step % 20 == 0:
   #     print(step, sess.run([x_data, y_data]))

print(sess.run([y]))
# Out:
# [array([15.208284], dtype=float32)]

# %% [markdown]
# <p>Back to [0_tf_hello_world.ipynb](0_tf_hello_world.ipynb).</p>
# <p>Next to [2_mnist.ipynb](2_mnist.ipynb).</p>
